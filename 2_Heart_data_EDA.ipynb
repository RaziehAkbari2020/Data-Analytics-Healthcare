# %% [markdown]
# <a href="https://colab.research.google.com/github/RaziehAkbari2020/Data-Analytics-Healthcare/blob/main/2_Heart_data_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Second Step is EDA:
# In this step we want to review the Data and get the understanding of it

# %% [markdown]
# ## **Exploratory Data Analysis![Untitled.jpg](data:image/jpeg;base64,...)**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f0b31a46-6ae4-4f25-bde9-2e8d2ed0bb5b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f0b31a46-6ae4-4f25-bde9-2e8d2ed0bb5b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('heart.csv')

# %%
import numpy as np

# %%
pip install dataprep
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 53.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 72.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.6/133.6 kB 15.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 56.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 57.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 96.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 764.0/764.0 kB 57.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 75.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 70.1 MB/s eta 0:00:00
# ...

# %%
#this code because of google colab is failed, but it is true in jupyter:

#from dataprep.eda import create_report
#report = create_report(df)
#report.show_browser()
# Out:
# Computing apply-c1befe1d3d2c2472d3a74167c99b468c:   0%|          | 0/1789 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/dask/core.py:121: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /usr/local/lib/python3.10/dist-packages/dataprep/eda/distribution/render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# /usr/local/lib/python3.10/dist-packages/dataprep/eda/distribution/render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# ...

# %%
from dataprep.eda import create_report
report = create_report(df)
report.save("eda_report.html")
# Out:
# Computing apply-c1befe1d3d2c2472d3a74167c99b468c:   0%|          | 0/1789 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/dask/core.py:121: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /usr/local/lib/python3.10/dist-packages/dataprep/eda/distribution/render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# /usr/local/lib/python3.10/dist-packages/dataprep/eda/distribution/render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# ...

# %%
from google.colab import files
files.download('eda_report.html')

# %% [markdown]
# In Addition to EDA, we can use this code to understand from data in general:

# %%
df.describe()
# Out:
#        Age (age in year)         sex  chest pain  blood pressure  \
# count         597.000000  597.000000  597.000000      597.000000
# mean           51.182580    0.701843    3.072027      132.125628
# std             9.074366    0.457833    0.965776       17.589254
# min            28.000000    0.000000    1.000000       92.000000
# 25%            44.000000    0.000000    2.000000      120.000000
# 50%            52.000000    1.000000    3.000000      130.000000
# 75%            58.000000    1.000000    4.000000      140.000000
# max            77.000000    1.000000    4.000000      200.000000
#
#        cholestoral   blood sugar  electrocardiographic   heart rate  \
# count    597.000000   597.000000             597.000000  597.000000
# mean     248.417923     0.108878               0.609715  144.458961
# std       58.631878     0.311747               0.868988   23.774396
# min       85.000000     0.000000               0.000000   71.000000
# ...
